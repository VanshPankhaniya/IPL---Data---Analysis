# %%
import numpy as np 
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\Vansh\Downloads\Ipl data set\matches.csv")

# %%
df
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
df.describe(include= "all")
# Out:
#                   id season    city        date match_type player_of_match  \
# count   1.095000e+03   1095    1044        1095       1095            1090
# unique           NaN     17      36         823          8             291
# top              NaN   2013  Mumbai  2017-04-09     League  AB de Villiers
# freq             NaN     76     173           2       1029              25
# mean    9.048283e+05    NaN     NaN         NaN        NaN             NaN
# std     3.677402e+05    NaN     NaN         NaN        NaN             NaN
# min     3.359820e+05    NaN     NaN         NaN        NaN             NaN
# 25%     5.483315e+05    NaN     NaN         NaN        NaN             NaN
# 50%     9.809610e+05    NaN     NaN         NaN        NaN             NaN
# 75%     1.254062e+06    NaN     NaN         NaN        NaN             NaN
# max     1.426312e+06    NaN     NaN         NaN        NaN             NaN
#
#                venue                        team1           team2  \
# ...

# %%
df.drop(["venue"],axis = 1 , inplace = True)

# %%
df["match_type"].isnull().sum()
# Out:
# 0

# %%
df.dropna(how="any",inplace = True)
df.isnull().sum()
# Out:
# id                 0
# season             0
# city               0
# date               0
# match_type         0
# player_of_match    0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# winner             0
# result             0
# result_margin      0
# target_runs        0
# target_overs       0
# super_over         0
# method             0
# umpire1            0
# umpire2            0
# dtype: int64

# %%
df.head(4)
# Out:
#         id   season       city        date match_type   player_of_match  \
# 38  336022  2007/08      Delhi  2008-05-17     League  DPMD Jayawardene
# 41  336025  2007/08    Kolkata  2008-05-18     League           M Ntini
# 60  392183     2009  Cape Town  2009-04-19     League        DL Vettori
# 63  392186     2009     Durban  2009-04-21     League          CH Gayle
#
#                     team1                  team2            toss_winner  \
# 38       Delhi Daredevils        Kings XI Punjab       Delhi Daredevils
# 41  Kolkata Knight Riders    Chennai Super Kings  Kolkata Knight Riders
# 60       Delhi Daredevils        Kings XI Punjab       Delhi Daredevils
# 63        Kings XI Punjab  Kolkata Knight Riders  Kolkata Knight Riders
#
#    toss_decision                 winner   result  result_margin  target_runs  \
# 38           bat        Kings XI Punjab     runs            6.0         89.0
# 41           bat    Chennai Super Kings     runs            3.0         53.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21 entries, 38 to 1023
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               21 non-null     int64
#  1   season           21 non-null     object
#  2   city             21 non-null     object
#  3   date             21 non-null     object
#  4   match_type       21 non-null     object
#  5   player_of_match  21 non-null     object
#  6   team1            21 non-null     object
#  7   team2            21 non-null     object
#  8   toss_winner      21 non-null     object
#  9   toss_decision    21 non-null     object
#  10  winner           21 non-null     object
#  11  result           21 non-null     object
#  12  result_margin    21 non-null     float64
#  13  target_runs      21 non-null     float64
#  14  target_overs     21 non-null     float64
#  15  super_over       21 non-null     object
#  16  method           21 non-null     object
# ...

# %%
df.isnull().sum()
# Out:
# id                 0
# season             0
# city               0
# date               0
# match_type         0
# player_of_match    0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# winner             0
# result             0
# result_margin      0
# target_runs        0
# target_overs       0
# super_over         0
# method             0
# umpire1            0
# umpire2            0
# dtype: int64

# %%
df.dtypes
# Out:
# id                   int64
# season              object
# city                object
# date                object
# match_type          object
# player_of_match     object
# team1               object
# team2               object
# toss_winner         object
# toss_decision       object
# winner              object
# result              object
# result_margin      float64
# target_runs        float64
# target_overs       float64
# super_over          object
# method              object
# umpire1             object
# umpire2             object
# dtype: object

# %%
df.head()
# Out:
#         id   season       city        date match_type   player_of_match  \
# 38  336022  2007/08      Delhi  2008-05-17     League  DPMD Jayawardene
# 41  336025  2007/08    Kolkata  2008-05-18     League           M Ntini
# 60  392183     2009  Cape Town  2009-04-19     League        DL Vettori
# 63  392186     2009     Durban  2009-04-21     League          CH Gayle
# 89  392214     2009  Centurion  2009-05-07     League         ML Hayden
#
#                     team1                  team2            toss_winner  \
# 38       Delhi Daredevils        Kings XI Punjab       Delhi Daredevils
# 41  Kolkata Knight Riders    Chennai Super Kings  Kolkata Knight Riders
# 60       Delhi Daredevils        Kings XI Punjab       Delhi Daredevils
# 63        Kings XI Punjab  Kolkata Knight Riders  Kolkata Knight Riders
# 89    Chennai Super Kings        Kings XI Punjab    Chennai Super Kings
#
#    toss_decision                 winner   result  result_margin  target_runs  \
# ...

# %%
df["id"]
# Out:
# 38       336022
# 41       336025
# 60       392183
# 63       392186
# 89       392214
# 192      501215
# 221      501245
# 231      501255
# 429      733993
# 476      829743
# 508      829807
# 538      980943
# 561      980989
# 565      980997
# 566      980999
# 633     1082648
# 641     1136566
# 653     1136578
# 667     1136592
# 951     1359476
# 1023    1370353
# Name: id, dtype: int64

# %%
df["id"].unique()
# Out:
# array([ 336022,  336025,  392183,  392186,  392214,  501215,  501245,
#         501255,  733993,  829743,  829807,  980943,  980989,  980997,
#         980999, 1082648, 1136566, 1136578, 1136592, 1359476, 1370353],
#       dtype=int64)

# %%
df.head()
# Out:
#         id   season       city        date match_type   player_of_match  \
# 38  336022  2007/08      Delhi  2008-05-17     League  DPMD Jayawardene
# 41  336025  2007/08    Kolkata  2008-05-18     League           M Ntini
# 60  392183     2009  Cape Town  2009-04-19     League        DL Vettori
# 63  392186     2009     Durban  2009-04-21     League          CH Gayle
# 89  392214     2009  Centurion  2009-05-07     League         ML Hayden
#
#                     team1                  team2            toss_winner  \
# 38       Delhi Daredevils        Kings XI Punjab       Delhi Daredevils
# 41  Kolkata Knight Riders    Chennai Super Kings  Kolkata Knight Riders
# 60       Delhi Daredevils        Kings XI Punjab       Delhi Daredevils
# 63        Kings XI Punjab  Kolkata Knight Riders  Kolkata Knight Riders
# 89    Chennai Super Kings        Kings XI Punjab    Chennai Super Kings
#
#    toss_decision                 winner   result  result_margin  target_runs  \
# ...

# %%
df.season
# Out:
# 38      2007/08
# 41      2007/08
# 60         2009
# 63         2009
# 89         2009
# 192        2011
# 221        2011
# 231        2011
# 429        2014
# 476        2015
# 508        2015
# 538        2016
# 561        2016
# 565        2016
# 566        2016
# 633        2017
# 641        2018
# 653        2018
# 667        2018
# 951        2023
# 1023       2023
# Name: season, dtype: object

# %%
df["season"].unique()
# Out:
# array(['2007/08', '2009', '2011', '2014', '2015', '2016', '2017', '2018',
#        '2023'], dtype=object)

# %%
df.isnull().sum()
# Out:
# id                 0
# season             0
# city               0
# date               0
# match_type         0
# player_of_match    0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# winner             0
# result             0
# result_margin      0
# target_runs        0
# target_overs       0
# super_over         0
# method             0
# umpire1            0
# umpire2            0
# dtype: int64

# %%
df_id=lambda x: str(x).split('/')[0]
df.id=df.id.apply(df_id)
df["id"].head()
# Out:
# 38    336022
# 41    336025
# 60    392183
# 63    392186
# 89    392214
# Name: id, dtype: object

# %%
df.head()
# Out:
#         id   season       city        date match_type   player_of_match  \
# 38  336022  2007/08      Delhi  2008-05-17     League  DPMD Jayawardene
# 41  336025  2007/08    Kolkata  2008-05-18     League           M Ntini
# 60  392183     2009  Cape Town  2009-04-19     League        DL Vettori
# 63  392186     2009     Durban  2009-04-21     League          CH Gayle
# 89  392214     2009  Centurion  2009-05-07     League         ML Hayden
#
#                     team1                  team2            toss_winner  \
# 38       Delhi Daredevils        Kings XI Punjab       Delhi Daredevils
# 41  Kolkata Knight Riders    Chennai Super Kings  Kolkata Knight Riders
# 60       Delhi Daredevils        Kings XI Punjab       Delhi Daredevils
# 63        Kings XI Punjab  Kolkata Knight Riders  Kolkata Knight Riders
# 89    Chennai Super Kings        Kings XI Punjab    Chennai Super Kings
#
#    toss_decision                 winner   result  result_margin  target_runs  \
# ...

# %%
df.target_runs
# Out:
# 38       89.0
# 41       53.0
# 60       54.0
# 63       69.0
# 89      187.0
# 192     135.0
# 221      52.0
# 231     102.0
# 429      43.0
# 476     118.0
# 508      81.0
# 538      61.0
# 561      66.0
# 565      58.0
# 566     203.0
# 633      48.0
# 641      71.0
# 653     125.0
# 667     151.0
# 951     154.0
# 1023    171.0
# Name: target_runs, dtype: float64

# %%
df["target_runs"].unique()
# Out:
# array([ 89.,  53.,  54.,  69., 187., 135.,  52., 102.,  43., 118.,  81.,
#         61.,  66.,  58., 203.,  48.,  71., 125., 151., 154., 171.])

# %%
df["target_runs"] = df["target_runs"].astype(str)
df["target_runs"] = df["target_runs"].apply(lambda x:x.replace(',','.'))
df["target_runs"] = df["target_runs"].astype(float)
df["target_runs"].head()
# Out:
# 38     89.0
# 41     53.0
# 60     54.0
# 63     69.0
# 89    187.0
# Name: target_runs, dtype: float64

# %%
df["target_runs"] = df["target_runs"].astype(str)
df["target_runs"] = df["target_runs"].apply(lambda x:x.replace(',','.'))
df["target_runs"] = df["target_runs"].astype(float)
df["target_runs"] = df["target_runs"].apply(lambda x:x/2)
df["target_runs"].head()
# Out:
# 38    44.5
# 41    26.5
# 60    27.0
# 63    34.5
# 89    93.5
# Name: target_runs, dtype: float64

# %%
df.dtypes
# Out:
# id                  object
# season              object
# city                object
# date                object
# match_type          object
# player_of_match     object
# team1               object
# team2               object
# toss_winner         object
# toss_decision       object
# winner              object
# result              object
# result_margin      float64
# target_runs        float64
# target_overs       float64
# super_over          object
# method              object
# umpire1             object
# umpire2             object
# dtype: object

# %%
df.shape
# Out:
# (21, 19)

# %%
df.size
# Out:
# 399

# %%
df.describe()
# Out:
#        result_margin  target_runs  target_overs
# count      21.000000    21.000000     21.000000
# mean       13.238095    49.785714     10.723810
# std        17.140317    25.054227      3.909208
# min         3.000000    21.500000      5.000000
# 25%         6.000000    29.000000      8.000000
# 50%         8.000000    40.500000     11.000000
# 75%        11.000000    67.500000     13.000000
# max        82.000000   101.500000     18.000000

# %%
df.duplicated()
# Out:
# 38      False
# 41      False
# 60      False
# 63      False
# 89      False
# 192     False
# 221     False
# 231     False
# 429     False
# 476     False
# 508     False
# 538     False
# 561     False
# 565     False
# 566     False
# 633     False
# 641     False
# 653     False
# 667     False
# 951     False
# 1023    False
# dtype: bool

# %%
fig, ax = plt.subplots(figsize=(10,6))
sns.countplot(x = "target_overs",data = df, ax =ax)
for i in ax.containers:
    ax.bar_label(i)
plt.title("Match target")
# Out:
# Text(0.5, 1.0, 'Match target')

# %%
df["result"].value_counts()[:].plot(kind = "line",figsize = (11,9),color = "red",title = "best result").grid(color = "black",linestyle = "--",linewidth = 2)

# %%
df.head(1)
# Out:
#         id   season   city        date match_type   player_of_match  \
# 38  336022  2007/08  Delhi  2008-05-17     League  DPMD Jayawardene
#
#                team1            team2       toss_winner toss_decision  \
# 38  Delhi Daredevils  Kings XI Punjab  Delhi Daredevils           bat
#
#              winner result  result_margin  target_runs  target_overs  \
# 38  Kings XI Punjab   runs            6.0         44.5           8.0
#
#    super_over method         umpire1      umpire2
# 38          N    D/L  AV Jayaprakash  RE Koertzen

# %%
df.groupby("team1")["result"].count().nlargest(7).plot(kind= "pie",autopct ="%1.1f%%")
# Out:
# <Axes: ylabel='result'>

# %%
df.head()
# Out:
#         id   season       city        date match_type   player_of_match  \
# 38  336022  2007/08      Delhi  2008-05-17     League  DPMD Jayawardene
# 41  336025  2007/08    Kolkata  2008-05-18     League           M Ntini
# 60  392183     2009  Cape Town  2009-04-19     League        DL Vettori
# 63  392186     2009     Durban  2009-04-21     League          CH Gayle
# 89  392214     2009  Centurion  2009-05-07     League         ML Hayden
#
#                     team1                  team2            toss_winner  \
# 38       Delhi Daredevils        Kings XI Punjab       Delhi Daredevils
# 41  Kolkata Knight Riders    Chennai Super Kings  Kolkata Knight Riders
# 60       Delhi Daredevils        Kings XI Punjab       Delhi Daredevils
# 63        Kings XI Punjab  Kolkata Knight Riders  Kolkata Knight Riders
# 89    Chennai Super Kings        Kings XI Punjab    Chennai Super Kings
#
#    toss_decision                 winner   result  result_margin  target_runs  \
# ...

# %%
plt.subplots(figsize= (9,9))
sns.countplot(x = "city", data = df,palette = "rainbow")
plt.title("matches in city")
# Out:
# Text(0.5, 1.0, 'matches in city')

# %%
fig = plt.figure(figsize = (9,9))
ax= fig.gca()
sns.boxplot(x = df["target_runs"],y = df["target_overs"])
plt.show()

# %%
sns.violinplot(x = df["target_runs"], y = df["result_margin"])
plt.show()

# %%
g = plt.subplots(figsize = (10,8))
df["city"].value_counts().head(15).plot(kind = "pie")
# Out:
# <Axes: ylabel='count'>

# %%
df["result"].value_counts()[:12].plot(kind = "bar",figsize = (9,9))
plt.title("Types of result")
# Out:
# Text(0.5, 1.0, 'Types of result')

# %%
df.head(2)
# Out:
#         id   season     city        date match_type   player_of_match  \
# 38  336022  2007/08    Delhi  2008-05-17     League  DPMD Jayawardene
# 41  336025  2007/08  Kolkata  2008-05-18     League           M Ntini
#
#                     team1                team2            toss_winner  \
# 38       Delhi Daredevils      Kings XI Punjab       Delhi Daredevils
# 41  Kolkata Knight Riders  Chennai Super Kings  Kolkata Knight Riders
#
#    toss_decision               winner result  result_margin  target_runs  \
# 38           bat      Kings XI Punjab   runs            6.0         44.5
# 41           bat  Chennai Super Kings   runs            3.0         26.5
#
#     target_overs super_over method         umpire1      umpire2
# 38           8.0          N    D/L  AV Jayaprakash  RE Koertzen
# 41           8.0          N    D/L       Asad Rauf  K Hariharan

# %%
plt.figure(figsize= (9,9))
sns.boxplot(x = df["target_overs"],y = df["target_runs"])
plt.show()

# %%
df["city"].value_counts()[:10].plot(kind = "bar",figsize = (10,9))
plt.title("Type of Services")
# Out:
# Text(0.5, 1.0, 'Type of Services')

# %%
df.head(1)
# Out:
#         id   season   city        date match_type   player_of_match  \
# 38  336022  2007/08  Delhi  2008-05-17     League  DPMD Jayawardene
#
#                team1            team2       toss_winner toss_decision  \
# 38  Delhi Daredevils  Kings XI Punjab  Delhi Daredevils           bat
#
#              winner result  result_margin  target_runs  target_overs  \
# 38  Kings XI Punjab   runs            6.0         44.5           8.0
#
#    super_over method         umpire1      umpire2
# 38          N    D/L  AV Jayaprakash  RE Koertzen

# %%
df["id"].value_counts().plot(kind = "line", figsize = (13,4))
plt.title("identyfy of city")
# Out:
# Text(0.5, 1.0, 'identyfy of city')

# %%
plt.figure(figsize = (16,8))
a = df["city"].value_counts()[:10]
sns.barplot(x= a , y = a .index, palette = "rainbow")
plt.title("Many types of city")
plt.xlabel("number of outlets", size = 16)
plt.ylabel("city_name", size = 10)
# Out:
# Text(0, 0.5, 'city_name')

# %%
sns.countplot(df["city"])
sns.countplot(df["city"]).set_xticklabels(sns.countplot(df["city"]).get_xticklabels(),rotation = 89)
fig = plt.gfc()
fig.set_size_inches(17,6)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 sns.countplot(df["city"])
# ...

# %%
loc_votes_df= df[["city","result"]]

# %%
loc_votes_df.drop_duplicates()
# Out:
#                city   result
# 38            Delhi     runs
# 41          Kolkata     runs
# 60        Cape Town  wickets
# 63           Durban     runs
# 89        Centurion     runs
# 192           Kochi  wickets
# 231       Bangalore  wickets
# 429           Delhi  wickets
# 476   Visakhapatnam     runs
# 508       Hyderabad  wickets
# 538       Hyderabad     runs
# 561         Kolkata  wickets
# 566       Bangalore     runs
# 641          Jaipur     runs
# 951      Chandigarh     runs
# 1023      Ahmedabad  wickets

# %%
cuisines_id_df = df[["city","id"]]

# %%
cuisines_id_df.drop_duplicates()
# Out:
#                city       id
# 38            Delhi   336022
# 41          Kolkata   336025
# 60        Cape Town   392183
# 63           Durban   392186
# 89        Centurion   392214
# 192           Kochi   501215
# 221         Kolkata   501245
# 231       Bangalore   501255
# 429           Delhi   733993
# 476   Visakhapatnam   829743
# 508       Hyderabad   829807
# 538       Hyderabad   980943
# 561         Kolkata   980989
# 565   Visakhapatnam   980997
# 566       Bangalore   980999
# 633       Bangalore  1082648
# 641          Jaipur  1136566
# 653         Kolkata  1136578
# 667           Delhi  1136592
# 951      Chandigarh  1359476
# 1023      Ahmedabad  1370353

# %%
df.tail(2)
# Out:
#            id season        city        date match_type player_of_match  \
# 951   1359476   2023  Chandigarh  2023-04-01     League  Arshdeep Singh
# 1023  1370353   2023   Ahmedabad  2023-05-29      Final       DP Conway
#
#                team1                  team2            toss_winner  \
# 951     Punjab Kings  Kolkata Knight Riders  Kolkata Knight Riders
# 1023  Gujarat Titans    Chennai Super Kings    Chennai Super Kings
#
#      toss_decision               winner   result  result_margin  target_runs  \
# 951          field         Punjab Kings     runs            7.0         77.0
# 1023         field  Chennai Super Kings  wickets            5.0         85.5
#
#       target_overs super_over method       umpire1    umpire2
# 951           16.0          N    D/L  BNJ Oxenford   YC Barde
# 1023          15.0          N    D/L   Nitin Menon  RJ Tucker

# %% [markdown]
# # EDA :-

# %%
df.hist(figsize=(15,9),color="g")
# Out:
# array([[<Axes: title={'center': 'result_margin'}>,
#         <Axes: title={'center': 'target_runs'}>],
#        [<Axes: title={'center': 'target_overs'}>, <Axes: >]], dtype=object)

# %%
df.head()
# Out:
#         id   season       city        date match_type   player_of_match  \
# 38  336022  2007/08      Delhi  2008-05-17     League  DPMD Jayawardene
# 41  336025  2007/08    Kolkata  2008-05-18     League           M Ntini
# 60  392183     2009  Cape Town  2009-04-19     League        DL Vettori
# 63  392186     2009     Durban  2009-04-21     League          CH Gayle
# 89  392214     2009  Centurion  2009-05-07     League         ML Hayden
#
#                     team1                  team2            toss_winner  \
# 38       Delhi Daredevils        Kings XI Punjab       Delhi Daredevils
# 41  Kolkata Knight Riders    Chennai Super Kings  Kolkata Knight Riders
# 60       Delhi Daredevils        Kings XI Punjab       Delhi Daredevils
# 63        Kings XI Punjab  Kolkata Knight Riders  Kolkata Knight Riders
# 89    Chennai Super Kings        Kings XI Punjab    Chennai Super Kings
#
#    toss_decision                 winner   result  result_margin  target_runs  \
# ...

# %%
sns.pairplot(df)
# Out:
# C:\Users\Vansh\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Vansh\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Vansh\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
